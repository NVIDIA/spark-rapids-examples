# %% [markdown]
# # TPC DS scale factor 10 - Apache Spark acceleration on GPU with RAPIDS Spark
#
# based on https://colab.research.google.com/github/LucaCanali/Miscellaneous/blob/master/Performance_Testing/TPCDS_PySpark/Labs_and_Notes/TPCDS_PySpark_getstarted.ipynb#scrollTo=6bab7772

# %% [markdown]
# # Download TPC-DS 10GiB Scale Parquet Dataset

# %%
# !pip install --quiet tpcds_pyspark pyspark==3.5.0 sparkmeasure pandas matplotlib

# %%
import os
from importlib.resources import files
from pyspark.sql import SparkSession
from tpcds_pyspark import TPCDS
import pandas as pd

# %%
tpcds_pyspark_files = files('tpcds_pyspark')

# %%
if not os.path.isdir('tpcds_10'):
  if not os.path.isfile('tpcds_10.zip'):
    # !wget https://sparkdltrigger.web.cern.ch/sparkdltrigger/TPCDS/tpcds_10.zip
  # !unzip -q tpcds_10.zip
# Out:
# --2024-10-18 20:38:45--  https://sparkdltrigger.web.cern.ch/sparkdltrigger/TPCDS/tpcds_10.zip
# Resolving sparkdltrigger.web.cern.ch (sparkdltrigger.web.cern.ch)... 2001:1458:d00:62::100:2e8, 2001:1458:d00:16::41d, 2001:1458:d00:65::100:265, ...
# Connecting to sparkdltrigger.web.cern.ch (sparkdltrigger.web.cern.ch)|2001:1458:d00:62::100:2e8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2888130422 (2.7G) [application/zip]
# Saving to: ‘tpcds_10.zip’
#
# tpcds_10.zip        100%[===================>]   2.69G   747KB/s    in 42m 2s
#
# 2024-10-18 21:20:47 (1.09 MB/s) - ‘tpcds_10.zip’ saved [2888130422/2888130422]

# %% [markdown]
# # Init a SparkSession with RAPIDS Spark

# %%
spark = (
    SparkSession.builder
      .appName('TPCDS PySpark RAPIDS=ON/OFF')
      .config('spark.driver.memory', '5g')
      .config('spark.plugins', 'com.nvidia.spark.SQLPlugin')
      .config('spark.jars', tpcds_pyspark_files.joinpath('spark-measure_2.12-0.24.jar'))
      .config('spark.jars.packages', 'com.nvidia:rapids-4-spark_2.12:24.08.0')
      .getOrCreate()
)
# Out:
# 24/10/18 21:22:37 WARN Utils: Your hostname, 73d57f4-lcelt resolves to a loopback address: 127.0.1.1; using 192.168.1.209 instead (on interface wlp0s20f3)
# 24/10/18 21:22:37 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/gshegalov/.local/share/virtualenvs/jupyter-juFhdvmw/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/gshegalov/.ivy2/cache
# The jars for the packages stored in: /home/gshegalov/.ivy2/jars
# com.nvidia#rapids-4-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-20d06318-4840-46bb-9dec-770127812d79;1.0
# 	confs: [default]
# 	found com.nvidia#rapids-4-spark_2.12;24.08.0 in central
# :: resolution report :: resolve 84ms :: artifacts dl 3ms
# 	:: modules in use:
# 	com.nvidia#rapids-4-spark_2.12;24.08.0 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   1   |   0   |   0   |   0   ||   1   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-20d06318-4840-46bb-9dec-770127812d79
# 	confs: [default]
# 	0 artifacts copied, 1 already retrieved (0kB/3ms)
# 24/10/18 21:22:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/18 21:22:39 WARN RapidsPluginUtils: RAPIDS Accelerator 24.08.0 using cudf 24.08.0, private revision 9fac64da220ddd6bf5626bd7bd1dd74c08603eac
# 24/10/18 21:22:39 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 24/10/18 21:22:39 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `NOT_ON_GPU`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.

# %% [markdown]
# # Verify SQL Acceleration on GPU can be enabled by checking the query plan and the GPU RAM in the "Resources" tab

# %%
spark.conf.set('spark.rapids.sql.enabled', True)
sum_df = spark.range(1000).selectExpr('SUM(*)')
sum_df.collect()
sum_df.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    GpuColumnarToRow false, [loreId=22]
#    +- GpuHashAggregate (keys=[], functions=[gpubasicsum(id#0L, LongType, false)]), filters=ArrayBuffer(None)) [loreId=21]
#       +- GpuShuffleCoalesce 1073741824, [loreId=20]
#          +- ShuffleQueryStage 0
#             +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=64], [loreId=17]
#                +- GpuHashAggregate (keys=[], functions=[partial_gpubasicsum(id#0L, LongType, false)]), filters=ArrayBuffer(None)) [loreId=16]
#                   +- GpuRange (0, 1000, step=1, splits=16)
# +- == Initial Plan ==
#    HashAggregate(keys=[], functions=[sum(id#0L)])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=11]
#       +- HashAggregate(keys=[], functions=[partial_sum(id#0L)])
#          +- Range (0, 1000, step=1, splits=16)

# %%
# https://github.com/LucaCanali/Miscellaneous/tree/master/Performance_Testing/TPCDS_PySpark/tpcds_pyspark/Queries

# queries = None to run all (takes much longer)
queries = None
queries = [
    'q14a',
    'q14b',
    'q23a',
    'q23b',
    'q24a',
    'q24b',
    'q88',
]

# %%
tpcds = TPCDS(data_path="./tpcds_10", num_runs=1, queries_repeat_times=1, queries=queries)
# Out:
# sparkMeasure jar path: /home/gshegalov/.local/share/virtualenvs/jupyter-juFhdvmw/lib/python3.10/site-packages/tpcds_pyspark/spark-measure_2.12-0.24.jar
# TPCDS queries path: /home/gshegalov/.local/share/virtualenvs/jupyter-juFhdvmw/lib/python3.10/site-packages/tpcds_pyspark/Queries
# 24/10/18 21:23:07 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# # Register TPC-DS tables before running queries

# %%
tpcds.map_tables()
# Out:
# Creating temporary view catalog_returns
# 24/10/18 21:23:16 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Creating temporary view catalog_sales
# Creating temporary view inventory
# Creating temporary view store_returns
# Creating temporary view store_sales
# Creating temporary view web_returns
# Creating temporary view web_sales
# Creating temporary view call_center
# Creating temporary view catalog_page
# Creating temporary view customer
# Creating temporary view customer_address
# Creating temporary view customer_demographics
# Creating temporary view date_dim
# Creating temporary view household_demographics
# Creating temporary view income_band
# Creating temporary view item
# Creating temporary view promotion
# Creating temporary view reason
# Creating temporary view ship_mode
# Creating temporary view store
# Creating temporary view time_dim
# Creating temporary view warehouse
# Creating temporary view web_page
# Creating temporary view web_site

# %% [markdown]
# # Measure Apache Spark CPU

# %%
tpcds.spark.conf.set('spark.rapids.sql.enabled', False)
tpcds.run_TPCDS()
# Out:
# Run 0 - query q14a - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:23:22
# ...Elapsed Time = 15.19 sec
# ...Executors Run Time = 150.58 sec
# ...Executors CPU Time = 92.16 sec
# ...Executors JVM GC Time = 13.13 sec
# ...Average Active Tasks = 9.9
#
# Run 0 - query q14b - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:23:42
# ...Elapsed Time = 8.47 sec
# ...Executors Run Time = 99.93 sec
# ...Executors CPU Time = 73.23 sec
# ...Executors JVM GC Time = 10.54 sec
# ...Average Active Tasks = 11.8
#
# Run 0 - query q23a - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:23:53
# ...Elapsed Time = 14.36 sec
# ...Executors Run Time = 170.7 sec
# ...Executors CPU Time = 123.13 sec
# ...Executors JVM GC Time = 21.74 sec
# ...Average Active Tasks = 11.9
#
# Run 0 - query q23b - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:24:08
# ...Elapsed Time = 15.41 sec
# ...Executors Run Time = 186.21 sec
# ...Executors CPU Time = 139.25 sec
# ...Executors JVM GC Time = 24.15 sec
# ...Average Active Tasks = 12.1
#
# Run 0 - query q24a - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:24:25
# ...Elapsed Time = 6.42 sec
# ...Executors Run Time = 64.95 sec
# ...Executors CPU Time = 47.44 sec
# ...Executors JVM GC Time = 9.83 sec
# ...Average Active Tasks = 10.1
#
# Run 0 - query q24b - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:24:33
# ...Elapsed Time = 4.72 sec
# ...Executors Run Time = 41.43 sec
# ...Executors CPU Time = 30.29 sec
# ...Executors JVM GC Time = 7.35 sec
# ...Average Active Tasks = 8.8
#
# Run 0 - query q88 - attempt 0 - starting...
# Job finished
# ...Start Time = 2024-10-18 21:24:38
# ...Elapsed Time = 2.6 sec
# ...Executors Run Time = 36.08 sec
# ...Executors CPU Time = 26.18 sec
# ...Executors JVM GC Time = 1.8 sec
# ...Average Active Tasks = 13.9

# %%
cpu_grouped_results = tpcds.grouped_results_pdf[['query', 'elapsedTime']].copy()

# %%
cpu_grouped_results
# Out:
#   query  elapsedTime
# 0  q14a        15186
# 1  q14b         8474
# 2  q23a        14360
# 3  q23b        15411
# 4  q24a         6415
# 5  q24b         4717
# 6   q88         2603

# %% [markdown]
# # Measure Apache Spark GPU

# %%
tpcds.spark.conf.set('spark.rapids.sql.enabled', True)
tpcds.run_TPCDS()
# Out:
# Run 0 - query q14a - attempt 0 - starting...
# 24/10/18 21:25:12 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:09
# ...Elapsed Time = 7.13 sec
# ...Executors Run Time = 44.7 sec
# ...Executors CPU Time = 15.58 sec
# ...Executors JVM GC Time = 2.54 sec
# ...Average Active Tasks = 6.3
#
# Run 0 - query q14b - attempt 0 - starting...
# 24/10/18 21:25:21 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:20
# ...Elapsed Time = 3.09 sec
# ...Executors Run Time = 28.9 sec
# ...Executors CPU Time = 12.01 sec
# ...Executors JVM GC Time = 0.92 sec
# ...Average Active Tasks = 9.3
#
# Run 0 - query q23a - attempt 0 - starting...
# 24/10/18 21:25:25 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:25
# ...Elapsed Time = 3.74 sec
# ...Executors Run Time = 39.08 sec
# ...Executors CPU Time = 16.68 sec
# ...Executors JVM GC Time = 1.02 sec
# ...Average Active Tasks = 10.4
#
# Run 0 - query q23b - attempt 0 - starting...
# 24/10/18 21:25:30 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:30
# ...Elapsed Time = 4.32 sec
# ...Executors Run Time = 47.85 sec
# ...Executors CPU Time = 18.25 sec
# ...Executors JVM GC Time = 1.54 sec
# ...Average Active Tasks = 11.1
#
# Run 0 - query q24a - attempt 0 - starting...
# 24/10/18 21:25:36 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:36
# ...Elapsed Time = 3.23 sec
# ...Executors Run Time = 24.03 sec
# ...Executors CPU Time = 8.63 sec
# ...Executors JVM GC Time = 0.69 sec
# ...Average Active Tasks = 7.4
#
# Run 0 - query q24b - attempt 0 - starting...
# 24/10/18 21:25:40 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
# Job finished
# ...Start Time = 2024-10-18 21:25:40
# ...Elapsed Time = 3.04 sec
# ...Executors Run Time = 21.31 sec
# ...Executors CPU Time = 8.02 sec
# ...Executors JVM GC Time = 0.67 sec
# ...Average Active Tasks = 7.0
#
# Run 0 - query q88 - attempt 0 - starting...
# 24/10/18 21:25:45 WARN GpuOverrides:
# ! <OverwriteByExpressionExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.datasources.v2.OverwriteByExpressionExec
#
# [Stage 608:>(3 + 16) / 20][Stage 610:>  (0 + 0) / 1][Stage 612:>  (0 + 0) / 1]
# Job finished
# ...Start Time = 2024-10-18 21:25:44
# ...Elapsed Time = 1.4 sec
# ...Executors Run Time = 17.36 sec
# ...Executors CPU Time = 2.49 sec
# ...Executors JVM GC Time = 0.32 sec
# ...Average Active Tasks = 12.4

# %% [markdown]
# # Show Speedup Factors achieved by GPU

# %%
gpu_grouped_results = tpcds.grouped_results_pdf[['query', 'elapsedTime']].copy()

# %%
gpu_grouped_results
# Out:
#   query  elapsedTime
# 0  q14a         7132
# 1  q14b         3092
# 2  q23a         3740
# 3  q23b         4318
# 4  q24a         3234
# 5  q24b         3035
# 6   q88         1395

# %%
res = pd.merge(cpu_grouped_results, gpu_grouped_results, on='query', how='inner', suffixes=['_cpu', '_gpu'])

# %%
res['speedup'] = res['elapsedTime_cpu'] / res['elapsedTime_gpu']

# %%
res = res.sort_values(by='elapsedTime_cpu', ascending=False)

# %%
res.plot(title='TPC-DS query elapsedTime on CPU vs GPU (lower is better)', kind='bar', x='query', y=['elapsedTime_cpu', 'elapsedTime_gpu'])
# Out:
# <Axes: title={'center': 'TPC-DS query elapsedTime on CPU vs GPU (lower is better)'}, xlabel='query'>

# %%
res.plot(title='Speedup factors of TPC-DS queries on GPU', kind='bar', x='query', y='speedup' )
# Out:
# <Axes: title={'center': 'Speedup factors of TPC-DS queries on GPU'}, xlabel='query'>

# %% [markdown]
# # Run Queries interactively

# %%
query = 'q88'
with open(f"{tpcds_pyspark_files}/Queries/{query}.sql") as f:
  q = f.read()

# %%
print(q)
# Out:
# SELECT *
# FROM
#   (SELECT count(*) h8_30_to_9
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 8
#     AND time_dim.t_minute >= 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s1,
#   (SELECT count(*) h9_to_9_30
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 9
#     AND time_dim.t_minute < 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s2,
#   (SELECT count(*) h9_30_to_10
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 9
#     AND time_dim.t_minute >= 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s3,
#   (SELECT count(*) h10_to_10_30
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 10
#     AND time_dim.t_minute < 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s4,
#   (SELECT count(*) h10_30_to_11
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 10
#     AND time_dim.t_minute >= 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s5,
#   (SELECT count(*) h11_to_11_30
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 11
#     AND time_dim.t_minute < 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s6,
#   (SELECT count(*) h11_30_to_12
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 11
#     AND time_dim.t_minute >= 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s7,
#   (SELECT count(*) h12_to_12_30
#   FROM store_sales, household_demographics, time_dim, store
#   WHERE ss_sold_time_sk = time_dim.t_time_sk
#     AND ss_hdemo_sk = household_demographics.hd_demo_sk
#     AND ss_store_sk = s_store_sk
#     AND time_dim.t_hour = 12
#     AND time_dim.t_minute < 30
#     AND (
#     (household_demographics.hd_dep_count = 4 AND household_demographics.hd_vehicle_count <= 4 + 2)
#       OR
#       (household_demographics.hd_dep_count = 2 AND household_demographics.hd_vehicle_count <= 2 + 2)
#       OR
#       (household_demographics.hd_dep_count = 0 AND
#         household_demographics.hd_vehicle_count <= 0 + 2))
#     AND store.s_store_name = 'ese') s8

# %%
spark.conf.set('spark.rapids.sql.enabled', True)
df  = spark.sql(q)
df.collect()
# Out:
# [Row(h8_30_to_9=18440, h9_to_9_30=39156, h9_30_to_10=38666, h10_to_10_30=58037, h10_30_to_11=58313, h11_to_11_30=34436, h11_30_to_12=33322, h12_to_12_30=39142)]

# %%
df.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    GpuColumnarToRow false, [loreId=1466]
#    +- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h12_to_12_30#71709L], 1073741824, [loreId=1465]
#       :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h11_30_to_12#71708L], 1073741824, [loreId=1464]
#       :  :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h11_to_11_30#71707L], 1073741824, [loreId=1463]
#       :  :  :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h10_30_to_11#71706L], 1073741824, [loreId=1462]
#       :  :  :  :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h10_to_10_30#71705L], 1073741824, [loreId=1461]
#       :  :  :  :  :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h9_30_to_10#71704L], 1073741824, [loreId=1460]
#       :  :  :  :  :  :- GpuBroadcastNestedLoopJoin Inner, GpuBuildRight, [h9_to_9_30#71703L], 1073741824, [loreId=1459]
#       :  :  :  :  :  :  :- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1458]
#       :  :  :  :  :  :  :  +- GpuShuffleCoalesce 1073741824, [loreId=1457]
#       :  :  :  :  :  :  :     +- ShuffleQueryStage 38
#       :  :  :  :  :  :  :        +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=368361], [loreId=1034]
#       :  :  :  :  :  :  :           +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1033]
#       :  :  :  :  :  :  :              +- GpuProject [loreId=1032]
#       :  :  :  :  :  :  :                 +- GpuBroadcastHashJoin [ss_sold_time_sk#198], [t_time_sk#749], Inner, GpuBuildRight, [loreId=1031]
#       :  :  :  :  :  :  :                    :- GpuProject [ss_sold_time_sk#198], [loreId=1030]
#       :  :  :  :  :  :  :                    :  +- GpuBroadcastHashJoin [ss_hdemo_sk#202], [hd_demo_sk#575], Inner, GpuBuildRight, [loreId=1029]
#       :  :  :  :  :  :  :                    :     :- GpuProject [ss_sold_time_sk#198, ss_hdemo_sk#202], [loreId=1028]
#       :  :  :  :  :  :  :                    :     :  +- GpuBroadcastHashJoin [ss_store_sk#204], [s_store_sk#691], Inner, GpuBuildRight, [loreId=1027]
#       :  :  :  :  :  :  :                    :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1026]
#       :  :  :  :  :  :  :                    :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#204) AND gpuisnotnull(ss_hdemo_sk#202)) AND gpuisnotnull(ss_sold_time_sk#198)), [loreId=1025]
#       :  :  :  :  :  :  :                    :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#198,ss_hdemo_sk#202,ss_store_sk#204] Batched: true, DataFilters: [isnotnull(ss_store_sk#204), isnotnull(ss_hdemo_sk#202), isnotnull(ss_sold_time_sk#198)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :  :  :  :  :  :                    :     :     +- BroadcastQueryStage 0
#       :  :  :  :  :  :  :                    :     :        +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :  :  :  :  :  :                    :     :           +- GpuProject [s_store_sk#691], [loreId=601]
#       :  :  :  :  :  :  :                    :     :              +- GpuCoalesceBatches targetsize(1073741824), [loreId=600]
#       :  :  :  :  :  :  :                    :     :                 +- GpuFilter ((gpuisnotnull(s_store_name#696) AND (s_store_name#696 = ese)) AND gpuisnotnull(s_store_sk#691)), [loreId=599]
#       :  :  :  :  :  :  :                    :     :                    +- GpuFileGpuScan parquet [s_store_sk#691,s_store_name#696] Batched: true, DataFilters: [isnotnull(s_store_name#696), (s_store_name#696 = ese), isnotnull(s_store_sk#691)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store], PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#       :  :  :  :  :  :  :                    :     +- BroadcastQueryStage 1
#       :  :  :  :  :  :  :                    :        +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :  :  :  :  :  :                    :           +- GpuProject [hd_demo_sk#575], [loreId=610]
#       :  :  :  :  :  :  :                    :              +- GpuCoalesceBatches targetsize(1073741824), [loreId=609]
#       :  :  :  :  :  :  :                    :                 +- GpuFilter (((((hd_dep_count#578 = 4) AND (hd_vehicle_count#579 <= 6)) OR ((hd_dep_count#578 = 2) AND (hd_vehicle_count#579 <= 4))) OR ((hd_dep_count#578 = 0) AND (hd_vehicle_count#579 <= 2))) AND gpuisnotnull(hd_demo_sk#575)), [loreId=608]
#       :  :  :  :  :  :  :                    :                    +- GpuFileGpuScan parquet [hd_demo_sk#575,hd_dep_count#578,hd_vehicle_count#579] Batched: true, DataFilters: [((((hd_dep_count#578 = 4) AND (hd_vehicle_count#579 <= 6)) OR ((hd_dep_count#578 = 2) AND (hd_ve..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/househ..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#       :  :  :  :  :  :  :                    +- BroadcastQueryStage 2
#       :  :  :  :  :  :  :                       +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365557], [loreId=620]
#       :  :  :  :  :  :  :                          +- GpuProject [t_time_sk#749], [loreId=619]
#       :  :  :  :  :  :  :                             +- GpuCoalesceBatches targetsize(1073741824), [loreId=618]
#       :  :  :  :  :  :  :                                +- GpuFilter ((((gpuisnotnull(t_hour#752) AND gpuisnotnull(t_minute#753)) AND (t_hour#752 = 8)) AND (t_minute#753 >= 30)) AND gpuisnotnull(t_time_sk#749)), [loreId=617]
#       :  :  :  :  :  :  :                                   +- GpuFileGpuScan parquet [t_time_sk#749,t_hour#752,t_minute#753] Batched: true, DataFilters: [isnotnull(t_hour#752), isnotnull(t_minute#753), (t_hour#752 = 8), (t_minute#753 >= 30), isnotnul..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,8), GreaterThanOrEqual(t_minute,30), IsNo..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  :  :  :  :  :  +- BroadcastQueryStage 47
#       :  :  :  :  :  :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370135], [loreId=1337]
#       :  :  :  :  :  :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1336]
#       :  :  :  :  :  :           +- GpuShuffleCoalesce 1073741824, [loreId=1335]
#       :  :  :  :  :  :              +- ShuffleQueryStage 40
#       :  :  :  :  :  :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369242], [loreId=1158]
#       :  :  :  :  :  :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1157]
#       :  :  :  :  :  :                       +- GpuProject [loreId=1156]
#       :  :  :  :  :  :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#71711], [t_time_sk#71738], Inner, GpuBuildRight, [loreId=1155]
#       :  :  :  :  :  :                             :- GpuProject [ss_sold_time_sk#71711], [loreId=1154]
#       :  :  :  :  :  :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#71715], [hd_demo_sk#71733], Inner, GpuBuildRight, [loreId=1153]
#       :  :  :  :  :  :                             :     :- GpuProject [ss_sold_time_sk#71711, ss_hdemo_sk#71715], [loreId=1152]
#       :  :  :  :  :  :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#71717], [s_store_sk#71748], Inner, GpuBuildRight, [loreId=1151]
#       :  :  :  :  :  :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1150]
#       :  :  :  :  :  :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#71717) AND gpuisnotnull(ss_hdemo_sk#71715)) AND gpuisnotnull(ss_sold_time_sk#71711)), [loreId=1149]
#       :  :  :  :  :  :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#71711,ss_hdemo_sk#71715,ss_store_sk#71717] Batched: true, DataFilters: [isnotnull(ss_store_sk#71717), isnotnull(ss_hdemo_sk#71715), isnotnull(ss_sold_time_sk#71711)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :  :  :  :  :                             :     :     +- BroadcastQueryStage 4
#       :  :  :  :  :  :                             :     :        +- ReusedExchange [s_store_sk#71748], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :  :  :  :  :                             :     +- BroadcastQueryStage 6
#       :  :  :  :  :  :                             :        +- ReusedExchange [hd_demo_sk#71733], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :  :  :  :  :                             +- BroadcastQueryStage 7
#       :  :  :  :  :  :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365672], [loreId=647]
#       :  :  :  :  :  :                                   +- GpuProject [t_time_sk#71738], [loreId=646]
#       :  :  :  :  :  :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=645]
#       :  :  :  :  :  :                                         +- GpuFilter ((((gpuisnotnull(t_hour#71741) AND gpuisnotnull(t_minute#71742)) AND (t_hour#71741 = 9)) AND (t_minute#71742 < 30)) AND gpuisnotnull(t_time_sk#71738)), [loreId=644]
#       :  :  :  :  :  :                                            +- GpuFileGpuScan parquet [t_time_sk#71738,t_hour#71741,t_minute#71742] Batched: true, DataFilters: [isnotnull(t_hour#71741), isnotnull(t_minute#71742), (t_hour#71741 = 9), (t_minute#71742 < 30), i..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,9), LessThan(t_minute,30), IsNotNull(t_ti..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  :  :  :  :  +- BroadcastQueryStage 48
#       :  :  :  :  :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370288], [loreId=1360]
#       :  :  :  :  :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1359]
#       :  :  :  :  :           +- GpuShuffleCoalesce 1073741824, [loreId=1358]
#       :  :  :  :  :              +- ShuffleQueryStage 41
#       :  :  :  :  :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369318], [loreId=1179]
#       :  :  :  :  :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1178]
#       :  :  :  :  :                       +- GpuProject [loreId=1177]
#       :  :  :  :  :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#71778], [t_time_sk#71805], Inner, GpuBuildRight, [loreId=1176]
#       :  :  :  :  :                             :- GpuProject [ss_sold_time_sk#71778], [loreId=1175]
#       :  :  :  :  :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#71782], [hd_demo_sk#71800], Inner, GpuBuildRight, [loreId=1174]
#       :  :  :  :  :                             :     :- GpuProject [ss_sold_time_sk#71778, ss_hdemo_sk#71782], [loreId=1173]
#       :  :  :  :  :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#71784], [s_store_sk#71815], Inner, GpuBuildRight, [loreId=1172]
#       :  :  :  :  :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1171]
#       :  :  :  :  :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#71784) AND gpuisnotnull(ss_hdemo_sk#71782)) AND gpuisnotnull(ss_sold_time_sk#71778)), [loreId=1170]
#       :  :  :  :  :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#71778,ss_hdemo_sk#71782,ss_store_sk#71784] Batched: true, DataFilters: [isnotnull(ss_store_sk#71784), isnotnull(ss_hdemo_sk#71782), isnotnull(ss_sold_time_sk#71778)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :  :  :  :                             :     :     +- BroadcastQueryStage 9
#       :  :  :  :  :                             :     :        +- ReusedExchange [s_store_sk#71815], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :  :  :  :                             :     +- BroadcastQueryStage 11
#       :  :  :  :  :                             :        +- ReusedExchange [hd_demo_sk#71800], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :  :  :  :                             +- BroadcastQueryStage 12
#       :  :  :  :  :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365789], [loreId=674]
#       :  :  :  :  :                                   +- GpuProject [t_time_sk#71805], [loreId=673]
#       :  :  :  :  :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=672]
#       :  :  :  :  :                                         +- GpuFilter ((((gpuisnotnull(t_hour#71808) AND gpuisnotnull(t_minute#71809)) AND (t_hour#71808 = 9)) AND (t_minute#71809 >= 30)) AND gpuisnotnull(t_time_sk#71805)), [loreId=671]
#       :  :  :  :  :                                            +- GpuFileGpuScan parquet [t_time_sk#71805,t_hour#71808,t_minute#71809] Batched: true, DataFilters: [isnotnull(t_hour#71808), isnotnull(t_minute#71809), (t_hour#71808 = 9), (t_minute#71809 >= 30), ..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,9), GreaterThanOrEqual(t_minute,30), IsNo..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  :  :  :  +- BroadcastQueryStage 46
#       :  :  :  :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=369974], [loreId=1312]
#       :  :  :  :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1311]
#       :  :  :  :           +- GpuShuffleCoalesce 1073741824, [loreId=1310]
#       :  :  :  :              +- ShuffleQueryStage 39
#       :  :  :  :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=368437], [loreId=1055]
#       :  :  :  :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1054]
#       :  :  :  :                       +- GpuProject [loreId=1053]
#       :  :  :  :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#71845], [t_time_sk#71872], Inner, GpuBuildRight, [loreId=1052]
#       :  :  :  :                             :- GpuProject [ss_sold_time_sk#71845], [loreId=1051]
#       :  :  :  :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#71849], [hd_demo_sk#71867], Inner, GpuBuildRight, [loreId=1050]
#       :  :  :  :                             :     :- GpuProject [ss_sold_time_sk#71845, ss_hdemo_sk#71849], [loreId=1049]
#       :  :  :  :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#71851], [s_store_sk#71882], Inner, GpuBuildRight, [loreId=1048]
#       :  :  :  :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1047]
#       :  :  :  :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#71851) AND gpuisnotnull(ss_hdemo_sk#71849)) AND gpuisnotnull(ss_sold_time_sk#71845)), [loreId=1046]
#       :  :  :  :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#71845,ss_hdemo_sk#71849,ss_store_sk#71851] Batched: true, DataFilters: [isnotnull(ss_store_sk#71851), isnotnull(ss_hdemo_sk#71849), isnotnull(ss_sold_time_sk#71845)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :  :  :                             :     :     +- BroadcastQueryStage 14
#       :  :  :  :                             :     :        +- ReusedExchange [s_store_sk#71882], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :  :  :                             :     +- BroadcastQueryStage 16
#       :  :  :  :                             :        +- ReusedExchange [hd_demo_sk#71867], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :  :  :                             +- BroadcastQueryStage 17
#       :  :  :  :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365906], [loreId=701]
#       :  :  :  :                                   +- GpuProject [t_time_sk#71872], [loreId=700]
#       :  :  :  :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=699]
#       :  :  :  :                                         +- GpuFilter ((((gpuisnotnull(t_hour#71875) AND gpuisnotnull(t_minute#71876)) AND (t_hour#71875 = 10)) AND (t_minute#71876 < 30)) AND gpuisnotnull(t_time_sk#71872)), [loreId=698]
#       :  :  :  :                                            +- GpuFileGpuScan parquet [t_time_sk#71872,t_hour#71875,t_minute#71876] Batched: true, DataFilters: [isnotnull(t_hour#71875), isnotnull(t_minute#71876), (t_hour#71875 = 10), (t_minute#71876 < 30), ..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,10), LessThan(t_minute,30), IsNotNull(t_t..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  :  :  +- BroadcastQueryStage 49
#       :  :  :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370429], [loreId=1381]
#       :  :  :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1380]
#       :  :  :           +- GpuShuffleCoalesce 1073741824, [loreId=1379]
#       :  :  :              +- ShuffleQueryStage 42
#       :  :  :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369396], [loreId=1200]
#       :  :  :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1199]
#       :  :  :                       +- GpuProject [loreId=1198]
#       :  :  :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#71912], [t_time_sk#71939], Inner, GpuBuildRight, [loreId=1197]
#       :  :  :                             :- GpuProject [ss_sold_time_sk#71912], [loreId=1196]
#       :  :  :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#71916], [hd_demo_sk#71934], Inner, GpuBuildRight, [loreId=1195]
#       :  :  :                             :     :- GpuProject [ss_sold_time_sk#71912, ss_hdemo_sk#71916], [loreId=1194]
#       :  :  :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#71918], [s_store_sk#71949], Inner, GpuBuildRight, [loreId=1193]
#       :  :  :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1192]
#       :  :  :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#71918) AND gpuisnotnull(ss_hdemo_sk#71916)) AND gpuisnotnull(ss_sold_time_sk#71912)), [loreId=1191]
#       :  :  :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#71912,ss_hdemo_sk#71916,ss_store_sk#71918] Batched: true, DataFilters: [isnotnull(ss_store_sk#71918), isnotnull(ss_hdemo_sk#71916), isnotnull(ss_sold_time_sk#71912)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :  :                             :     :     +- BroadcastQueryStage 19
#       :  :  :                             :     :        +- ReusedExchange [s_store_sk#71949], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :  :                             :     +- BroadcastQueryStage 21
#       :  :  :                             :        +- ReusedExchange [hd_demo_sk#71934], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :  :                             +- BroadcastQueryStage 22
#       :  :  :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=366023], [loreId=728]
#       :  :  :                                   +- GpuProject [t_time_sk#71939], [loreId=727]
#       :  :  :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=726]
#       :  :  :                                         +- GpuFilter ((((gpuisnotnull(t_hour#71942) AND gpuisnotnull(t_minute#71943)) AND (t_hour#71942 = 10)) AND (t_minute#71943 >= 30)) AND gpuisnotnull(t_time_sk#71939)), [loreId=725]
#       :  :  :                                            +- GpuFileGpuScan parquet [t_time_sk#71939,t_hour#71942,t_minute#71943] Batched: true, DataFilters: [isnotnull(t_hour#71942), isnotnull(t_minute#71943), (t_hour#71942 = 10), (t_minute#71943 >= 30),..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,10), GreaterThanOrEqual(t_minute,30), IsN..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  :  +- BroadcastQueryStage 50
#       :  :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370558], [loreId=1400]
#       :  :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1399]
#       :  :           +- GpuShuffleCoalesce 1073741824, [loreId=1398]
#       :  :              +- ShuffleQueryStage 43
#       :  :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369472], [loreId=1221]
#       :  :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1220]
#       :  :                       +- GpuProject [loreId=1219]
#       :  :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#71979], [t_time_sk#72006], Inner, GpuBuildRight, [loreId=1218]
#       :  :                             :- GpuProject [ss_sold_time_sk#71979], [loreId=1217]
#       :  :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#71983], [hd_demo_sk#72001], Inner, GpuBuildRight, [loreId=1216]
#       :  :                             :     :- GpuProject [ss_sold_time_sk#71979, ss_hdemo_sk#71983], [loreId=1215]
#       :  :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#71985], [s_store_sk#72016], Inner, GpuBuildRight, [loreId=1214]
#       :  :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1213]
#       :  :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#71985) AND gpuisnotnull(ss_hdemo_sk#71983)) AND gpuisnotnull(ss_sold_time_sk#71979)), [loreId=1212]
#       :  :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#71979,ss_hdemo_sk#71983,ss_store_sk#71985] Batched: true, DataFilters: [isnotnull(ss_store_sk#71985), isnotnull(ss_hdemo_sk#71983), isnotnull(ss_sold_time_sk#71979)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :  :                             :     :     +- BroadcastQueryStage 24
#       :  :                             :     :        +- ReusedExchange [s_store_sk#72016], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :  :                             :     +- BroadcastQueryStage 26
#       :  :                             :        +- ReusedExchange [hd_demo_sk#72001], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :  :                             +- BroadcastQueryStage 27
#       :  :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=366140], [loreId=755]
#       :  :                                   +- GpuProject [t_time_sk#72006], [loreId=754]
#       :  :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=753]
#       :  :                                         +- GpuFilter ((((gpuisnotnull(t_hour#72009) AND gpuisnotnull(t_minute#72010)) AND (t_hour#72009 = 11)) AND (t_minute#72010 < 30)) AND gpuisnotnull(t_time_sk#72006)), [loreId=752]
#       :  :                                            +- GpuFileGpuScan parquet [t_time_sk#72006,t_hour#72009,t_minute#72010] Batched: true, DataFilters: [isnotnull(t_hour#72009), isnotnull(t_minute#72010), (t_hour#72009 = 11), (t_minute#72010 < 30), ..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,11), LessThan(t_minute,30), IsNotNull(t_t..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       :  +- BroadcastQueryStage 51
#       :     +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370676], [loreId=1417]
#       :        +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1416]
#       :           +- GpuShuffleCoalesce 1073741824, [loreId=1415]
#       :              +- ShuffleQueryStage 44
#       :                 +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369548], [loreId=1242]
#       :                    +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1241]
#       :                       +- GpuProject [loreId=1240]
#       :                          +- GpuBroadcastHashJoin [ss_sold_time_sk#72046], [t_time_sk#72073], Inner, GpuBuildRight, [loreId=1239]
#       :                             :- GpuProject [ss_sold_time_sk#72046], [loreId=1238]
#       :                             :  +- GpuBroadcastHashJoin [ss_hdemo_sk#72050], [hd_demo_sk#72068], Inner, GpuBuildRight, [loreId=1237]
#       :                             :     :- GpuProject [ss_sold_time_sk#72046, ss_hdemo_sk#72050], [loreId=1236]
#       :                             :     :  +- GpuBroadcastHashJoin [ss_store_sk#72052], [s_store_sk#72083], Inner, GpuBuildRight, [loreId=1235]
#       :                             :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1234]
#       :                             :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#72052) AND gpuisnotnull(ss_hdemo_sk#72050)) AND gpuisnotnull(ss_sold_time_sk#72046)), [loreId=1233]
#       :                             :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#72046,ss_hdemo_sk#72050,ss_store_sk#72052] Batched: true, DataFilters: [isnotnull(ss_store_sk#72052), isnotnull(ss_hdemo_sk#72050), isnotnull(ss_sold_time_sk#72046)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#       :                             :     :     +- BroadcastQueryStage 29
#       :                             :     :        +- ReusedExchange [s_store_sk#72083], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#       :                             :     +- BroadcastQueryStage 31
#       :                             :        +- ReusedExchange [hd_demo_sk#72068], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#       :                             +- BroadcastQueryStage 32
#       :                                +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=366257], [loreId=782]
#       :                                   +- GpuProject [t_time_sk#72073], [loreId=781]
#       :                                      +- GpuCoalesceBatches targetsize(1073741824), [loreId=780]
#       :                                         +- GpuFilter ((((gpuisnotnull(t_hour#72076) AND gpuisnotnull(t_minute#72077)) AND (t_hour#72076 = 11)) AND (t_minute#72077 >= 30)) AND gpuisnotnull(t_time_sk#72073)), [loreId=779]
#       :                                            +- GpuFileGpuScan parquet [t_time_sk#72073,t_hour#72076,t_minute#72077] Batched: true, DataFilters: [isnotnull(t_hour#72076), isnotnull(t_minute#72077), (t_hour#72076 = 11), (t_minute#72077 >= 30),..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,11), GreaterThanOrEqual(t_minute,30), IsN..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#       +- BroadcastQueryStage 52
#          +- GpuBroadcastExchange IdentityBroadcastMode, [plan_id=370783], [loreId=1432]
#             +- GpuHashAggregate (keys=[], functions=[gpucount(1, false)]), filters=List(None)) [loreId=1431]
#                +- GpuShuffleCoalesce 1073741824, [loreId=1430]
#                   +- ShuffleQueryStage 45
#                      +- GpuColumnarExchange gpusinglepartitioning$(), ENSURE_REQUIREMENTS, [plan_id=369624], [loreId=1263]
#                         +- GpuHashAggregate (keys=[], functions=[partial_gpucount(1, false)]), filters=List(None)) [loreId=1262]
#                            +- GpuProject [loreId=1261]
#                               +- GpuBroadcastHashJoin [ss_sold_time_sk#72113], [t_time_sk#72140], Inner, GpuBuildRight, [loreId=1260]
#                                  :- GpuProject [ss_sold_time_sk#72113], [loreId=1259]
#                                  :  +- GpuBroadcastHashJoin [ss_hdemo_sk#72117], [hd_demo_sk#72135], Inner, GpuBuildRight, [loreId=1258]
#                                  :     :- GpuProject [ss_sold_time_sk#72113, ss_hdemo_sk#72117], [loreId=1257]
#                                  :     :  +- GpuBroadcastHashJoin [ss_store_sk#72119], [s_store_sk#72150], Inner, GpuBuildRight, [loreId=1256]
#                                  :     :     :- GpuCoalesceBatches targetsize(1073741824), [loreId=1255]
#                                  :     :     :  +- GpuFilter ((gpuisnotnull(ss_store_sk#72119) AND gpuisnotnull(ss_hdemo_sk#72117)) AND gpuisnotnull(ss_sold_time_sk#72113)), [loreId=1254]
#                                  :     :     :     +- GpuFileGpuScan parquet [ss_sold_time_sk#72113,ss_hdemo_sk#72117,ss_store_sk#72119] Batched: true, DataFilters: [isnotnull(ss_store_sk#72119), isnotnull(ss_hdemo_sk#72117), isnotnull(ss_sold_time_sk#72113)], Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/store_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#                                  :     :     +- BroadcastQueryStage 34
#                                  :     :        +- ReusedExchange [s_store_sk#72150], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365485], [loreId=602]
#                                  :     +- BroadcastQueryStage 36
#                                  :        +- ReusedExchange [hd_demo_sk#72135], GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=365521], [loreId=611]
#                                  +- BroadcastQueryStage 37
#                                     +- GpuBroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=366374], [loreId=809]
#                                        +- GpuProject [t_time_sk#72140], [loreId=808]
#                                           +- GpuCoalesceBatches targetsize(1073741824), [loreId=807]
#                                              +- GpuFilter ((((gpuisnotnull(t_hour#72143) AND gpuisnotnull(t_minute#72144)) AND (t_hour#72143 = 12)) AND (t_minute#72144 < 30)) AND gpuisnotnull(t_time_sk#72140)), [loreId=806]
#                                                 +- GpuFileGpuScan parquet [t_time_sk#72140,t_hour#72143,t_minute#72144] Batched: true, DataFilters: [isnotnull(t_hour#72143), isnotnull(t_minute#72144), (t_hour#72143 = 12), (t_minute#72144 < 30), ..., Format: Parquet, Location: InMemoryFileIndex[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_10/time_dim], PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,12), LessThan(t_minute,30), IsNotNull(t_t..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
# +- == Initial Plan ==
#    BroadcastNestedLoopJoin BuildRight, Inner
#    :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :  :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :  :  :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :  :  :  :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :  :  :  :  :- BroadcastNestedLoopJoin BuildRight, Inner
#    :  :  :  :  :  :  :- HashAggregate(keys=[], functions=[count(1)])
#    :  :  :  :  :  :  :  +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362539]
#    :  :  :  :  :  :  :     +- HashAggregate(keys=[], functions=[partial_count(1)])
#    :  :  :  :  :  :  :        +- Project
#    :  :  :  :  :  :  :           +- BroadcastHashJoin [ss_sold_time_sk#198], [t_time_sk#749], Inner, BuildRight, false
#    :  :  :  :  :  :  :              :- Project [ss_sold_time_sk#198]
#    :  :  :  :  :  :  :              :  +- BroadcastHashJoin [ss_hdemo_sk#202], [hd_demo_sk#575], Inner, BuildRight, false
#    :  :  :  :  :  :  :              :     :- Project [ss_sold_time_sk#198, ss_hdemo_sk#202]
#    :  :  :  :  :  :  :              :     :  +- BroadcastHashJoin [ss_store_sk#204], [s_store_sk#691], Inner, BuildRight, false
#    :  :  :  :  :  :  :              :     :     :- Filter ((isnotnull(ss_store_sk#204) AND isnotnull(ss_hdemo_sk#202)) AND isnotnull(ss_sold_time_sk#198))
#    :  :  :  :  :  :  :              :     :     :  +- FileScan parquet [ss_sold_time_sk#198,ss_hdemo_sk#202,ss_store_sk#204] Batched: true, DataFilters: [isnotnull(ss_store_sk#204), isnotnull(ss_hdemo_sk#202), isnotnull(ss_sold_time_sk#198)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#    :  :  :  :  :  :  :              :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362526]
#    :  :  :  :  :  :  :              :     :        +- Project [s_store_sk#691]
#    :  :  :  :  :  :  :              :     :           +- Filter ((isnotnull(s_store_name#696) AND (s_store_name#696 = ese)) AND isnotnull(s_store_sk#691))
#    :  :  :  :  :  :  :              :     :              +- FileScan parquet [s_store_sk#691,s_store_name#696] Batched: true, DataFilters: [isnotnull(s_store_name#696), (s_store_name#696 = ese), isnotnull(s_store_sk#691)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#    :  :  :  :  :  :  :              :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362530]
#    :  :  :  :  :  :  :              :        +- Project [hd_demo_sk#575]
#    :  :  :  :  :  :  :              :           +- Filter (((((hd_dep_count#578 = 4) AND (hd_vehicle_count#579 <= 6)) OR ((hd_dep_count#578 = 2) AND (hd_vehicle_count#579 <= 4))) OR ((hd_dep_count#578 = 0) AND (hd_vehicle_count#579 <= 2))) AND isnotnull(hd_demo_sk#575))
#    :  :  :  :  :  :  :              :              +- FileScan parquet [hd_demo_sk#575,hd_dep_count#578,hd_vehicle_count#579] Batched: true, DataFilters: [((((hd_dep_count#578 = 4) AND (hd_vehicle_count#579 <= 6)) OR ((hd_dep_count#578 = 2) AND (hd_ve..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#    :  :  :  :  :  :  :              +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362534]
#    :  :  :  :  :  :  :                 +- Project [t_time_sk#749]
#    :  :  :  :  :  :  :                    +- Filter ((((isnotnull(t_hour#752) AND isnotnull(t_minute#753)) AND (t_hour#752 = 8)) AND (t_minute#753 >= 30)) AND isnotnull(t_time_sk#749))
#    :  :  :  :  :  :  :                       +- FileScan parquet [t_time_sk#749,t_hour#752,t_minute#753] Batched: true, DataFilters: [isnotnull(t_hour#752), isnotnull(t_minute#753), (t_hour#752 = 8), (t_minute#753 >= 30), isnotnul..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,8), GreaterThanOrEqual(t_minute,30), IsNo..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#    :  :  :  :  :  :  +- BroadcastExchange IdentityBroadcastMode, [plan_id=362557]
#    :  :  :  :  :  :     +- HashAggregate(keys=[], functions=[count(1)])
#    :  :  :  :  :  :        +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362554]
#    :  :  :  :  :  :           +- HashAggregate(keys=[], functions=[partial_count(1)])
#    :  :  :  :  :  :              +- Project
#    :  :  :  :  :  :                 +- BroadcastHashJoin [ss_sold_time_sk#71711], [t_time_sk#71738], Inner, BuildRight, false
#    :  :  :  :  :  :                    :- Project [ss_sold_time_sk#71711]
#    :  :  :  :  :  :                    :  +- BroadcastHashJoin [ss_hdemo_sk#71715], [hd_demo_sk#71733], Inner, BuildRight, false
#    :  :  :  :  :  :                    :     :- Project [ss_sold_time_sk#71711, ss_hdemo_sk#71715]
#    :  :  :  :  :  :                    :     :  +- BroadcastHashJoin [ss_store_sk#71717], [s_store_sk#71748], Inner, BuildRight, false
#    :  :  :  :  :  :                    :     :     :- Filter ((isnotnull(ss_store_sk#71717) AND isnotnull(ss_hdemo_sk#71715)) AND isnotnull(ss_sold_time_sk#71711))
#    :  :  :  :  :  :                    :     :     :  +- FileScan parquet [ss_sold_time_sk#71711,ss_hdemo_sk#71715,ss_store_sk#71717] Batched: true, DataFilters: [isnotnull(ss_store_sk#71717), isnotnull(ss_hdemo_sk#71715), isnotnull(ss_sold_time_sk#71711)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#    :  :  :  :  :  :                    :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362541]
#    :  :  :  :  :  :                    :     :        +- Project [s_store_sk#71748]
#    :  :  :  :  :  :                    :     :           +- Filter ((isnotnull(s_store_name#71753) AND (s_store_name#71753 = ese)) AND isnotnull(s_store_sk#71748))
#    :  :  :  :  :  :                    :     :              +- FileScan parquet [s_store_sk#71748,s_store_name#71753] Batched: true, DataFilters: [isnotnull(s_store_name#71753), (s_store_name#71753 = ese), isnotnull(s_store_sk#71748)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#    :  :  :  :  :  :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362545]
#    :  :  :  :  :  :                    :        +- Project [hd_demo_sk#71733]
#    :  :  :  :  :  :                    :           +- Filter (((((hd_dep_count#71736 = 4) AND (hd_vehicle_count#71737 <= 6)) OR ((hd_dep_count#71736 = 2) AND (hd_vehicle_count#71737 <= 4))) OR ((hd_dep_count#71736 = 0) AND (hd_vehicle_count#71737 <= 2))) AND isnotnull(hd_demo_sk#71733))
#    :  :  :  :  :  :                    :              +- FileScan parquet [hd_demo_sk#71733,hd_dep_count#71736,hd_vehicle_count#71737] Batched: true, DataFilters: [((((hd_dep_count#71736 = 4) AND (hd_vehicle_count#71737 <= 6)) OR ((hd_dep_count#71736 = 2) AND ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#    :  :  :  :  :  :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362549]
#    :  :  :  :  :  :                       +- Project [t_time_sk#71738]
#    :  :  :  :  :  :                          +- Filter ((((isnotnull(t_hour#71741) AND isnotnull(t_minute#71742)) AND (t_hour#71741 = 9)) AND (t_minute#71742 < 30)) AND isnotnull(t_time_sk#71738))
#    :  :  :  :  :  :                             +- FileScan parquet [t_time_sk#71738,t_hour#71741,t_minute#71742] Batched: true, DataFilters: [isnotnull(t_hour#71741), isnotnull(t_minute#71742), (t_hour#71741 = 9), (t_minute#71742 < 30), i..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,9), LessThan(t_minute,30), IsNotNull(t_ti..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#    :  :  :  :  :  +- BroadcastExchange IdentityBroadcastMode, [plan_id=362575]
#    :  :  :  :  :     +- HashAggregate(keys=[], functions=[count(1)])
#    :  :  :  :  :        +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362572]
#    :  :  :  :  :           +- HashAggregate(keys=[], functions=[partial_count(1)])
#    :  :  :  :  :              +- Project
#    :  :  :  :  :                 +- BroadcastHashJoin [ss_sold_time_sk#71778], [t_time_sk#71805], Inner, BuildRight, false
#    :  :  :  :  :                    :- Project [ss_sold_time_sk#71778]
#    :  :  :  :  :                    :  +- BroadcastHashJoin [ss_hdemo_sk#71782], [hd_demo_sk#71800], Inner, BuildRight, false
#    :  :  :  :  :                    :     :- Project [ss_sold_time_sk#71778, ss_hdemo_sk#71782]
#    :  :  :  :  :                    :     :  +- BroadcastHashJoin [ss_store_sk#71784], [s_store_sk#71815], Inner, BuildRight, false
#    :  :  :  :  :                    :     :     :- Filter ((isnotnull(ss_store_sk#71784) AND isnotnull(ss_hdemo_sk#71782)) AND isnotnull(ss_sold_time_sk#71778))
#    :  :  :  :  :                    :     :     :  +- FileScan parquet [ss_sold_time_sk#71778,ss_hdemo_sk#71782,ss_store_sk#71784] Batched: true, DataFilters: [isnotnull(ss_store_sk#71784), isnotnull(ss_hdemo_sk#71782), isnotnull(ss_sold_time_sk#71778)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#    :  :  :  :  :                    :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362559]
#    :  :  :  :  :                    :     :        +- Project [s_store_sk#71815]
#    :  :  :  :  :                    :     :           +- Filter ((isnotnull(s_store_name#71820) AND (s_store_name#71820 = ese)) AND isnotnull(s_store_sk#71815))
# ...
#    :  :  :                    :     :        +- Project [s_store_sk#71949]
#    :  :  :                    :     :           +- Filter ((isnotnull(s_store_name#71954) AND (s_store_name#71954 = ese)) AND isnotnull(s_store_sk#71949))
#    :  :  :                    :     :              +- FileScan parquet [s_store_sk#71949,s_store_name#71954] Batched: true, DataFilters: [isnotnull(s_store_name#71954), (s_store_name#71954 = ese), isnotnull(s_store_sk#71949)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#    :  :  :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362599]
#    :  :  :                    :        +- Project [hd_demo_sk#71934]
#    :  :  :                    :           +- Filter (((((hd_dep_count#71937 = 4) AND (hd_vehicle_count#71938 <= 6)) OR ((hd_dep_count#71937 = 2) AND (hd_vehicle_count#71938 <= 4))) OR ((hd_dep_count#71937 = 0) AND (hd_vehicle_count#71938 <= 2))) AND isnotnull(hd_demo_sk#71934))
#    :  :  :                    :              +- FileScan parquet [hd_demo_sk#71934,hd_dep_count#71937,hd_vehicle_count#71938] Batched: true, DataFilters: [((((hd_dep_count#71937 = 4) AND (hd_vehicle_count#71938 <= 6)) OR ((hd_dep_count#71937 = 2) AND ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#    :  :  :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362603]
#    :  :  :                       +- Project [t_time_sk#71939]
#    :  :  :                          +- Filter ((((isnotnull(t_hour#71942) AND isnotnull(t_minute#71943)) AND (t_hour#71942 = 10)) AND (t_minute#71943 >= 30)) AND isnotnull(t_time_sk#71939))
#    :  :  :                             +- FileScan parquet [t_time_sk#71939,t_hour#71942,t_minute#71943] Batched: true, DataFilters: [isnotnull(t_hour#71942), isnotnull(t_minute#71943), (t_hour#71942 = 10), (t_minute#71943 >= 30),..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,10), GreaterThanOrEqual(t_minute,30), IsN..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#    :  :  +- BroadcastExchange IdentityBroadcastMode, [plan_id=362629]
#    :  :     +- HashAggregate(keys=[], functions=[count(1)])
#    :  :        +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362626]
#    :  :           +- HashAggregate(keys=[], functions=[partial_count(1)])
#    :  :              +- Project
#    :  :                 +- BroadcastHashJoin [ss_sold_time_sk#71979], [t_time_sk#72006], Inner, BuildRight, false
#    :  :                    :- Project [ss_sold_time_sk#71979]
#    :  :                    :  +- BroadcastHashJoin [ss_hdemo_sk#71983], [hd_demo_sk#72001], Inner, BuildRight, false
#    :  :                    :     :- Project [ss_sold_time_sk#71979, ss_hdemo_sk#71983]
#    :  :                    :     :  +- BroadcastHashJoin [ss_store_sk#71985], [s_store_sk#72016], Inner, BuildRight, false
#    :  :                    :     :     :- Filter ((isnotnull(ss_store_sk#71985) AND isnotnull(ss_hdemo_sk#71983)) AND isnotnull(ss_sold_time_sk#71979))
#    :  :                    :     :     :  +- FileScan parquet [ss_sold_time_sk#71979,ss_hdemo_sk#71983,ss_store_sk#71985] Batched: true, DataFilters: [isnotnull(ss_store_sk#71985), isnotnull(ss_hdemo_sk#71983), isnotnull(ss_sold_time_sk#71979)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#    :  :                    :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362613]
#    :  :                    :     :        +- Project [s_store_sk#72016]
#    :  :                    :     :           +- Filter ((isnotnull(s_store_name#72021) AND (s_store_name#72021 = ese)) AND isnotnull(s_store_sk#72016))
#    :  :                    :     :              +- FileScan parquet [s_store_sk#72016,s_store_name#72021] Batched: true, DataFilters: [isnotnull(s_store_name#72021), (s_store_name#72021 = ese), isnotnull(s_store_sk#72016)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#    :  :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362617]
#    :  :                    :        +- Project [hd_demo_sk#72001]
#    :  :                    :           +- Filter (((((hd_dep_count#72004 = 4) AND (hd_vehicle_count#72005 <= 6)) OR ((hd_dep_count#72004 = 2) AND (hd_vehicle_count#72005 <= 4))) OR ((hd_dep_count#72004 = 0) AND (hd_vehicle_count#72005 <= 2))) AND isnotnull(hd_demo_sk#72001))
#    :  :                    :              +- FileScan parquet [hd_demo_sk#72001,hd_dep_count#72004,hd_vehicle_count#72005] Batched: true, DataFilters: [((((hd_dep_count#72004 = 4) AND (hd_vehicle_count#72005 <= 6)) OR ((hd_dep_count#72004 = 2) AND ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#    :  :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362621]
#    :  :                       +- Project [t_time_sk#72006]
#    :  :                          +- Filter ((((isnotnull(t_hour#72009) AND isnotnull(t_minute#72010)) AND (t_hour#72009 = 11)) AND (t_minute#72010 < 30)) AND isnotnull(t_time_sk#72006))
#    :  :                             +- FileScan parquet [t_time_sk#72006,t_hour#72009,t_minute#72010] Batched: true, DataFilters: [isnotnull(t_hour#72009), isnotnull(t_minute#72010), (t_hour#72009 = 11), (t_minute#72010 < 30), ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,11), LessThan(t_minute,30), IsNotNull(t_t..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#    :  +- BroadcastExchange IdentityBroadcastMode, [plan_id=362647]
#    :     +- HashAggregate(keys=[], functions=[count(1)])
#    :        +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362644]
#    :           +- HashAggregate(keys=[], functions=[partial_count(1)])
#    :              +- Project
#    :                 +- BroadcastHashJoin [ss_sold_time_sk#72046], [t_time_sk#72073], Inner, BuildRight, false
#    :                    :- Project [ss_sold_time_sk#72046]
#    :                    :  +- BroadcastHashJoin [ss_hdemo_sk#72050], [hd_demo_sk#72068], Inner, BuildRight, false
#    :                    :     :- Project [ss_sold_time_sk#72046, ss_hdemo_sk#72050]
#    :                    :     :  +- BroadcastHashJoin [ss_store_sk#72052], [s_store_sk#72083], Inner, BuildRight, false
#    :                    :     :     :- Filter ((isnotnull(ss_store_sk#72052) AND isnotnull(ss_hdemo_sk#72050)) AND isnotnull(ss_sold_time_sk#72046))
#    :                    :     :     :  +- FileScan parquet [ss_sold_time_sk#72046,ss_hdemo_sk#72050,ss_store_sk#72052] Batched: true, DataFilters: [isnotnull(ss_store_sk#72052), isnotnull(ss_hdemo_sk#72050), isnotnull(ss_sold_time_sk#72046)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#    :                    :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362631]
#    :                    :     :        +- Project [s_store_sk#72083]
#    :                    :     :           +- Filter ((isnotnull(s_store_name#72088) AND (s_store_name#72088 = ese)) AND isnotnull(s_store_sk#72083))
#    :                    :     :              +- FileScan parquet [s_store_sk#72083,s_store_name#72088] Batched: true, DataFilters: [isnotnull(s_store_name#72088), (s_store_name#72088 = ese), isnotnull(s_store_sk#72083)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#    :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362635]
#    :                    :        +- Project [hd_demo_sk#72068]
#    :                    :           +- Filter (((((hd_dep_count#72071 = 4) AND (hd_vehicle_count#72072 <= 6)) OR ((hd_dep_count#72071 = 2) AND (hd_vehicle_count#72072 <= 4))) OR ((hd_dep_count#72071 = 0) AND (hd_vehicle_count#72072 <= 2))) AND isnotnull(hd_demo_sk#72068))
#    :                    :              +- FileScan parquet [hd_demo_sk#72068,hd_dep_count#72071,hd_vehicle_count#72072] Batched: true, DataFilters: [((((hd_dep_count#72071 = 4) AND (hd_vehicle_count#72072 <= 6)) OR ((hd_dep_count#72071 = 2) AND ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#    :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362639]
#    :                       +- Project [t_time_sk#72073]
#    :                          +- Filter ((((isnotnull(t_hour#72076) AND isnotnull(t_minute#72077)) AND (t_hour#72076 = 11)) AND (t_minute#72077 >= 30)) AND isnotnull(t_time_sk#72073))
#    :                             +- FileScan parquet [t_time_sk#72073,t_hour#72076,t_minute#72077] Batched: true, DataFilters: [isnotnull(t_hour#72076), isnotnull(t_minute#72077), (t_hour#72076 = 11), (t_minute#72077 >= 30),..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,11), GreaterThanOrEqual(t_minute,30), IsN..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>
#    +- BroadcastExchange IdentityBroadcastMode, [plan_id=362665]
#       +- HashAggregate(keys=[], functions=[count(1)])
#          +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=362662]
#             +- HashAggregate(keys=[], functions=[partial_count(1)])
#                +- Project
#                   +- BroadcastHashJoin [ss_sold_time_sk#72113], [t_time_sk#72140], Inner, BuildRight, false
#                      :- Project [ss_sold_time_sk#72113]
#                      :  +- BroadcastHashJoin [ss_hdemo_sk#72117], [hd_demo_sk#72135], Inner, BuildRight, false
#                      :     :- Project [ss_sold_time_sk#72113, ss_hdemo_sk#72117]
#                      :     :  +- BroadcastHashJoin [ss_store_sk#72119], [s_store_sk#72150], Inner, BuildRight, false
#                      :     :     :- Filter ((isnotnull(ss_store_sk#72119) AND isnotnull(ss_hdemo_sk#72117)) AND isnotnull(ss_sold_time_sk#72113))
#                      :     :     :  +- FileScan parquet [ss_sold_time_sk#72113,ss_hdemo_sk#72117,ss_store_sk#72119] Batched: true, DataFilters: [isnotnull(ss_store_sk#72119), isnotnull(ss_hdemo_sk#72117), isnotnull(ss_sold_time_sk#72113)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(ss_store_sk), IsNotNull(ss_hdemo_sk), IsNotNull(ss_sold_time_sk)], ReadSchema: struct<ss_sold_time_sk:int,ss_hdemo_sk:int,ss_store_sk:int>
#                      :     :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362649]
#                      :     :        +- Project [s_store_sk#72150]
#                      :     :           +- Filter ((isnotnull(s_store_name#72155) AND (s_store_name#72155 = ese)) AND isnotnull(s_store_sk#72150))
#                      :     :              +- FileScan parquet [s_store_sk#72150,s_store_name#72155] Batched: true, DataFilters: [isnotnull(s_store_name#72155), (s_store_name#72155 = ese), isnotnull(s_store_sk#72150)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(s_store_name), EqualTo(s_store_name,ese), IsNotNull(s_store_sk)], ReadSchema: struct<s_store_sk:int,s_store_name:string>
#                      :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362653]
#                      :        +- Project [hd_demo_sk#72135]
#                      :           +- Filter (((((hd_dep_count#72138 = 4) AND (hd_vehicle_count#72139 <= 6)) OR ((hd_dep_count#72138 = 2) AND (hd_vehicle_count#72139 <= 4))) OR ((hd_dep_count#72138 = 0) AND (hd_vehicle_count#72139 <= 2))) AND isnotnull(hd_demo_sk#72135))
#                      :              +- FileScan parquet [hd_demo_sk#72135,hd_dep_count#72138,hd_vehicle_count#72139] Batched: true, DataFilters: [((((hd_dep_count#72138 = 4) AND (hd_vehicle_count#72139 <= 6)) OR ((hd_dep_count#72138 = 2) AND ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [Or(Or(And(EqualTo(hd_dep_count,4),LessThanOrEqual(hd_vehicle_count,6)),And(EqualTo(hd_dep_count,..., ReadSchema: struct<hd_demo_sk:int,hd_dep_count:int,hd_vehicle_count:int>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=362657]
#                         +- Project [t_time_sk#72140]
#                            +- Filter ((((isnotnull(t_hour#72143) AND isnotnull(t_minute#72144)) AND (t_hour#72143 = 12)) AND (t_minute#72144 < 30)) AND isnotnull(t_time_sk#72140))
#                               +- FileScan parquet [t_time_sk#72140,t_hour#72143,t_minute#72144] Batched: true, DataFilters: [isnotnull(t_hour#72143), isnotnull(t_minute#72144), (t_hour#72143 = 12), (t_minute#72144 < 30), ..., Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/gshegalov/gits/gerashegalov/rapids-shell/src/jupyter/tpcds_..., PartitionFilters: [], PushedFilters: [IsNotNull(t_hour), IsNotNull(t_minute), EqualTo(t_hour,12), LessThan(t_minute,30), IsNotNull(t_t..., ReadSchema: struct<t_time_sk:int,t_hour:int,t_minute:int>

# %%
spark.conf.set('spark.rapids.sql.enabled', False)
df  = spark.sql(q)
df.collect()
# Out:
# [Row(h8_30_to_9=18440, h9_to_9_30=39156, h9_30_to_10=38666, h10_to_10_30=58037, h10_30_to_11=58313, h11_to_11_30=34436, h11_30_to_12=33322, h12_to_12_30=39142)]
